# %% [markdown]
# <a href="https://colab.research.google.com/github/ofzlo/NLP-tutorial/blob/main/3.%20Language%20Model/NLP_03_01_language_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 03. 언어 모델(Language Model)
# - 언어 모델(Language Model) : 단어 시퀀스(문장)에 확률을 할당하는 모델
#   - 문장의 적절성을 정확히 판단할수록 자연어 처리 성능이 뛰어나다 판단한다.
#   - 통계를 이용한 방법과 인공 신경망을 이용한 방법으로 구분한다.
#
# # 03-01 언어 모델(Language Model)이란?
# ## 1. 언어 모델(Language Model)
# - 단어 시퀀스에 확률을 할당(assign)하는 일을 하는 모델
#   - 가장 자연스러운 단어 시퀀스를 찾아내는 것
#   - 보편적으로 사용되는 방법: 이전 단어들이 주어졌을 때 다음 단어를 예측하도록 하는 것
#
# - **`언어 모델링(Language Modeling)`** : 주어진 단어들로부터 아직 모르는 단어를 예측하는 작업
#   - 이전 단어들로부터 다음 단어를 예측하는 일

# %% [markdown]
# ## 2. 단어 시퀀스의 확률 할당
# 1. 기계 번역(Machine Translation)
# 2. 오타 교정(Spell Correction)
# 3. 음성 인식(Speech Recognition)
#
# 확률을 통해 보다 적절한 문장을 판단한다.

# %% [markdown]
# ## 3. 주어진 이전 단어들로부터 다음 단어 예측하기
# - 이전 단어들이 주어졌을 때 다음 단어를 예측하는 방법
#
# ### **A. 단어 시퀀스의 확률**
# 하나의 단어를 w, 단어 시퀀스를 대문자 W라고 한다면, n개의 단어가 등장하는 단어 시퀀스 W의 확률
# ![](data:image/png;base64,...)
#
# ### **B. 다음 단어 등장 확률**
# n-1개의 단어가 나열된 상태에서 n번째 단어의 확률
# ![화면 캡처 2023-01-31 182535.png](data:image/png;base64,...)
#
# 전체 단어 시퀀스 W의 확률은 모든 단어가 예측되고 나서야 알 수 있으므로, 단어 시퀀스의 확률은 다음과 같다.
# ![화면 캡처 2023-01-31 182621.png](data:image/png;base64,...)
